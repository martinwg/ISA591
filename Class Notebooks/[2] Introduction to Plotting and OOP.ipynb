# %% [markdown]
# # Module 0 Worksheet: Python for Data Mining
#
# **Course:** Introduction to Data Mining for Business
# **Topics:** Pandas, Plotting, and Object-Oriented Programming
#
# This worksheet reviews core Python skills that will be used throughout the course. We will work with a real customer churn dataset throughout the Pandas and plotting sections.
#
# Complete the `TODO` items and short-answer questions directly in the notebook.

# %% [markdown]
# ## Learning goals
#
# By the end of this worksheet, you should be able to:
#
# 1. Read a CSV file into Pandas.
# 2. Inspect and summarize a DataFrame.
# 3. Select rows and columns using Pandas.
# 4. Filter observations and create new variables.
# 5. Check and handle missing or incorrectly stored values.
# 6. Create common plots for business data.
# 7. Explain the difference between a class and an object.
# 8. Instantiate a Python class and use its attributes and methods.
# 9. Recognize the same object-oriented pattern used by machine-learning libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
#
# # 1. Read the Telco Churn Dataset
#
# We will use the Telco Churn dataset throughout this worksheet.
#
# The dataset contains information about telecommunications customers, including:
# - customer demographics
# - services
# - tenure
# - monthly charges
# - total charges
# - whether the customer churned

# %%
customer_df = pd.read_csv("https://raw.githubusercontent.com/martinwg/ISA591/refs/heads/main/data/Telco_Churn.csv")

customer_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Practice 1A: Inspect the DataFrame
#
# Use Pandas to find:
#
# 1. the number of rows and columns
# 2. the first 5 observations
# 3. the column names

# %%
## .shape attribute shows the dimension of data
customer_df.shape

## # obs 
customer_df.shape[0]
# Out:
# 7043

# %%
## .head() print first few obs
## ,tail() print the last few 
## .head(10) 
customer_df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
## .columns attribute shows variable names
customer_df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# TODO
df_shape = None
first_five = None
column_names = None

print("Shape:", df_shape)
print("\nColumns:")
print(column_names)

print("\nFirst 5 observations:")
print(first_five)
# Out:
# Shape: None
#
# Columns:
# None
#
# First 5 observations:
# None

# %%
## Identifiers
hex(id(customer_df))
# Out:
# '0x1ead6e95850'

# %%
df = customer_df
hex(id(df))
# Out:
# '0x1ead6e95850'

# %%
## Proper Copy
df = customer_df.copy()
hex(id(df))
# Out:
# '0x1ead723ae50'

# %% [markdown]
# ## Practice 1B: Data types
#
# Use `.dtypes` to inspect the data types of all variables.
#
# Pay special attention to:
# - `tenure`
# - `MonthlyCharges`
# - `TotalCharges`
# - `Churn`

# %%
## .info() method for a summary of data, data types, missing values, memory usage
customer_df.info()
## str and object refer to categorical variables
## int and float refer to numeric 
## int8 (8 bits of memory) 
## float64 (64 bits of memory)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
customer_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
## Variable types
customer_df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# TODO
data_types = None
print(data_types)
# Out:
# None

# %% [markdown]
# ---
#
# # 2. Selecting Columns and Rows with Pandas

# %% [markdown]
# ## Practice 2A: Select one column
#
# Select the `MonthlyCharges` column as a Pandas Series.

# %%
## 1 single column
customer_df.MonthlyCharges
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
## NumPy array 
customer_df.MonthlyCharges.values
# Out:
# array([ 29.85,  56.95,  53.85, ...,  29.6 ,  74.4 , 105.65])

# %%
## subsetting approach
customer_df['MonthlyCharges']
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
customer_df[['MonthlyCharges']]
# Out:
#       MonthlyCharges
# 0              29.85
# 1              56.95
# 2              53.85
# 3              42.30
# 4              70.70
# ...              ...
# 7038           84.80
# 7039          103.20
# 7040           29.60
# 7041           74.40
# 7042          105.65
#
# [7043 rows x 1 columns]

# %%
# TODO
monthly_charges = None

print(monthly_charges.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 4
#       1 # TODO
#       2 monthly_charges = None
#       3
# ----> 4 print(monthly_charges.head())
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
## index subsetting

customer_df.iloc[:,0]  ## select variable 1
# Out:
# 0       7590-VHVEG
# 1       5575-GNVDE
# 2       3668-QPYBK
# 3       7795-CFOCW
# 4       9237-HQITU
#            ...
# 7038    6840-RESVB
# 7039    2234-XADUH
# 7040    4801-JZAZL
# 7041    8361-LTMKD
# 7042    3186-AJIEK
# Name: customerID, Length: 7043, dtype: object

# %% [markdown]
# ## Practice 2B: Select multiple columns
#
# Select these columns as a DataFrame:
#
# - `tenure`
# - `MonthlyCharges`
# - `Churn`

# %%
## use [list of variables] 
customer_df[['MonthlyCharges','tenure']]
# Out:
#       MonthlyCharges  tenure
# 0              29.85       1
# 1              56.95      34
# 2              53.85       2
# 3              42.30      45
# 4              70.70       2
# ...              ...     ...
# 7038           84.80      24
# 7039          103.20      72
# 7040           29.60      11
# 7041           74.40       4
# 7042          105.65      66
#
# [7043 rows x 2 columns]

# %%
# TODO
customer_subset = None

customer_subset.head()

# %% [markdown]
# ## Practice 2C: Select rows with `.iloc`
#
# Use `.iloc` to select the first 3 rows of the dataset.

# %%
customer_df.iloc[10:20, 5:]
# Out:
#     tenure PhoneService MultipleLines InternetService       OnlineSecurity  \
# 10      13          Yes            No             DSL                  Yes
# 11      16          Yes            No              No  No internet service
# 12      58          Yes           Yes     Fiber optic                   No
# 13      49          Yes           Yes     Fiber optic                   No
# 14      25          Yes            No     Fiber optic                  Yes
# 15      69          Yes           Yes     Fiber optic                  Yes
# 16      52          Yes            No              No  No internet service
# 17      71          Yes           Yes     Fiber optic                  Yes
# 18      10          Yes            No             DSL                   No
# 19      21          Yes            No     Fiber optic                   No
#
#            OnlineBackup     DeviceProtection          TechSupport  \
# 10                   No                   No                   No
# ...

# %%
# TODO
first_three_rows = None

first_three_rows

# %% [markdown]
# ## Practice 2D: Use `.loc`
#
# Set `customerID` as the index and use `.loc` to retrieve customer:
#
# `7590-VHVEG`

# %%
## SSN as an index
## df.set_index('SSN', inplace=True)
## df['123-45-6789']

# %%
customer_indexed = customer_df.set_index("customerID")

# TODO
customer_record = customer_indexed.loc["7590-VHVEG"]

customer_record
# Out:
# gender                        Female
# SeniorCitizen                      0
# Partner                          Yes
# Dependents                        No
# tenure                             1
# PhoneService                      No
# MultipleLines       No phone service
# InternetService                  DSL
# OnlineSecurity                    No
# OnlineBackup                     Yes
# DeviceProtection                  No
# TechSupport                       No
# StreamingTV                       No
# StreamingMovies                   No
# Contract              Month-to-month
# PaperlessBilling                 Yes
# PaymentMethod       Electronic check
# MonthlyCharges                 29.85
# TotalCharges                   29.85
# Churn                             No
# Name: 7590-VHVEG, dtype: object

# %%
customer_indexed
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# ...            ...            ...     ...        ...     ...          ...
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
# ...

# %% [markdown]
# ---
#
# # 3. Summary Statistics

# %% [markdown]
# ## Practice 3A: `.describe()`
#
# Use `.describe()` to summarize the numeric variables in the dataset.

# %%
## .describee() for min, max, mean, std, quartiles for numeric variables
customer_df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
## .value_counts() for categorical variables
customer_df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
# TODO
summary = None

summary

# %% [markdown]
# ## Practice 3B: Individual summaries
#
# Calculate:
#
# 1. average tenure
# 2. average monthly charges
# 3. maximum monthly charges

# %%
## .mean(), .median(), .std(), .var() for invidivual numeric variables
customer_df['MonthlyCharges'].mean()
# Out:
# 64.76169246059918

# %%
# TODO
mean_tenure = None
mean_monthly_charges = None
max_monthly_charges = None

print("Average tenure:", mean_tenure)
print("Average monthly charges:", mean_monthly_charges)
print("Maximum monthly charges:", max_monthly_charges)

# %% [markdown]
# ---
#
# # 4. Filtering Business Data

# %% [markdown]
# ## Practice 4A: High monthly charges
#
# Find all customers whose `MonthlyCharges` are greater than $100.

# %%
## filter data
## df[conditional]
## e.g., df["MonthlyCharges"] > 100 
## df['Service'] == "Monthly"
## (df["MonthlyCharges"] > 100)  &  (df['Service'] == "Monthly")
## You can use <, >, <=, >=, ==, != for comparisons and & for and, | for or, ~ for not

## I want average monthly charges less than 40
customer_df[customer_df['MonthlyCharges'] < 40]

## Female customers
customer_df[customer_df['gender'] == 'Female']

## fenmale customers with monthly charges less than 40
customer_df[(customer_df['MonthlyCharges'] < 40)  & (customer_df['gender'] == 'Female')]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 7     6713-OKOMC  Female              0      No         No      10
# 16    8191-XWSZG  Female              0      No         No      52
# 42    9867-JCZSP  Female              0     Yes        Yes      17
# 58    3957-SQXML  Female              0     Yes        Yes      34
# ...          ...     ...            ...     ...        ...     ...
# 7017  4807-IZYOZ  Female              0      No         No      51
# 7019  9710-NJERN  Female              0      No         No      39
# 7030  0871-OPBXW  Female              0      No         No       2
# 7037  2569-WGERO  Female              0      No         No      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
# TODO
high_charge_customers = None

high_charge_customers.head()

# %% [markdown]
# ## Practice 4B: Customers who churned
#
# Filter the dataset to include only customers where:
#
# `Churn == "Yes"`

# %%
# TODO
churned_customers = None

churned_customers.head()

# %% [markdown]
# ## Practice 4C: Multiple conditions
#
# Find customers who:
#
# - have a month-to-month contract
# - have monthly charges greater than $80
# - churned

# %%
# TODO
high_risk_customers = None

high_risk_customers.head()

# %% [markdown]
# ---
#
# # 5. Missing Values and Data Cleaning
#
# Before modeling, we need to make sure variables are stored correctly.
#
# In this dataset, `TotalCharges` may contain blank values stored as text.

# %%
## Get missing values by variable

customer_df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## Practice 5A: Check missing values

# %%
# TODO
missing_values = None

print(missing_values)

# %% [markdown]
# ## Practice 5B: Convert `TotalCharges` to numeric
#
# Use:
#
# `pd.to_numeric(..., errors="coerce")`
#
# Values that cannot be converted will become `NaN`.

# %%
customer_df['TotalCharges'] = pd.to_numeric(customer_df['TotalCharges'], errors = "coerce")  ## NAs for errors

# %%
customer_df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# TODO
customer_df["TotalCharges"] = None

print(customer_df["TotalCharges"].dtype)
print(customer_df["TotalCharges"].isna().sum())

# %% [markdown]
# ## Practice 6A: Create a binary churn variable
#
# Create:
#
# - `1` if `Churn == "Yes"`
# - `0` otherwise
#
# Call the new variable `ChurnBinary`.

# %%
## .map({value1: value2})

# %%
# TODO
customer_df["ChurnBinary"] = customer_df['Churn'].map({"Yes": 1, "No": 0})

customer_df[["Churn", "ChurnBinary"]].head()
# Out:
#   Churn  ChurnBinary
# 0    No            0
# 1    No            0
# 2   Yes            1
# 3    No            0
# 4   Yes            1

# %% [markdown]
# ---
#
# # 7. Plotting Business Data
#
# Plots help us understand distributions, relationships, trends, and unusual observations.
#
# We will practice:
#
# - histograms
# - boxplots
# - bar charts
# - scatter plots

# %% [markdown]
# ## Practice 7A: Histogram of monthly charges
#
# Create a histogram of `MonthlyCharges`.

# %%
## Empty Canvas
plt.figure(figsize=(8,4))

## plt.hist, plt.plot, plt.scatter
plt.hist(customer_df.MonthlyCharges, color = "red", bins = 40)
plt.title("Histogram of Monthly Charges")

## show the figure
plt.show()

# %% [markdown]
# ### Question
#
# What does a histogram help us understand?
#
# **Your response here:**
# - Shape of the data. If variable is very skewed, you might consider a transformation (log(MonthlyCharges))

# %% [markdown]
# ## Practice 7B: Histogram of tenure
#
# Create a histogram of `tenure`.

# %%
# TODO
# plt.figure(figsize=(8, 4))
# plt.hist(...)
# plt.title(...)
# plt.xlabel(...)
# plt.ylabel(...)
# plt.show()

# %% [markdown]
# ## Practice 7C: Boxplot of monthly charges
#
# Create a boxplot of `MonthlyCharges`.

# %%
## Determine possible outliers
plt.figure(figsize = (4,4))
plt.boxplot(customer_df['MonthlyCharges'])
plt.title("BoxPlot of Charges")
plt.show()

# %% [markdown]
# ## Practice 7D: Churn bar chart
#
# Create a bar chart showing the number of customers who:
#
# - churned
# - did not churn
#
# Hint:
#
# `customer_df["Churn"].value_counts()`

# %%
customer_df.Churn.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Churn'>

# %%
customer_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# TODO
### get a barplot of the variable partner

partner_counts = None

# churn_counts.plot(kind="bar")
# plt.title(...)
# plt.xlabel(...)
# plt.ylabel(...)
# plt.show()

# %% [markdown]
# ## Practice 7E: Scatter plot
#
# Create a scatter plot with:
#
# - `tenure` on the x-axis
# - `TotalCharges` on the y-axis

# %%
plot_df = customer_df.dropna()
plot_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
plot_df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
## you need to fix missing values for some plots
# plt.scatter(customer_df.tenure, customer_df.TotalCharges) ## missing values on TotalCharges

plot_df = customer_df.dropna(subset=["TotalCharges"])

# TODO
plt.figure(figsize=(8, 5))
plt.scatter(plot_df['tenure'], plot_df['TotalCharges'])
# plt.xlabel(...)
# plt.ylabel(...)
# plt.title(...)
plt.show()

# %% [markdown]
# ---
#
# # 8. Grouping and Comparing Customers

# %% [markdown]
# ## Practice 8A: Average monthly charges by churn status
#
# Use `.groupby()` to calculate average `MonthlyCharges` for:
#
# - `Churn = No`
# - `Churn = Yes`

# %%
# TODO
avg_charge_by_churn = None

print(avg_charge_by_churn)

# %% [markdown]
# ## Practice 8B: Average tenure by contract type
#
# Calculate the average `tenure` for each `Contract` type.

# %%
# TODO
avg_tenure_by_contract = None

print(avg_tenure_by_contract)

# %% [markdown]
# ---
#
# # 9. Object-Oriented Programming
#
# Python libraries frequently organize functionality using **classes**.
#
# A class is a blueprint for creating objects.
#
# Objects can have:
#
# - **attributes**: values associated with the object
# - **methods**: functions associated with the object

# %%
x = 5  ## instantiate an object from the class Int (x = Int(5) )

## attributes
x.denominator

## methods (function)
x.bit_count()
# Out:
# 2

# %%
customer_df.columns  ## instance of the class DataFrame
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
customer_df.MonthlyCharges.plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
## Run a Linear Regression
from sklearn.linear_model import LinearRegression ## importing the class LinearRegression

# %%
## Step 1. Make an Instance
myreg = LinearRegression() 

## Step 2. fit
## myreg.fit(X, y)

## Step 3. predict
# myreg.predict(X)

# %% [markdown]
# ## Practice 9A: A simple customer class
#
# Consider the following class:

# %%
class Customer:

    def __init__(self, customer_id, tenure, monthly_charges):
        self.customer_id = customer_id
        self.tenure = tenure
        self.monthly_charges = monthly_charges

    def estimated_annual_charges(self):
        return self.monthly_charges * 12

# %% [markdown]
# ## Practice 9B: Instantiate an object
#
# Create a customer with:
#
# - customer ID = `"ABC123"`
# - tenure = `24`
# - monthly charges = `75`

# %%
# TODO
customer1 = None

# %% [markdown]
# Access the object's attributes.

# %%
# TODO
# print(customer1.customer_id)
# print(customer1.tenure)
# print(customer1.monthly_charges)

# %% [markdown]
# Call the `estimated_annual_charges()` method.

# %%
# TODO
annual_charges = None

print("Estimated annual charges:", annual_charges)

# %% [markdown]
# ## Practice 9C: Class vs. object
#
# In the example above:
#
# 1. What is the **class**?
# 2. What is the **object/instance**?
# 3. Give one **attribute**.
# 4. Give one **method**.

# %% [markdown]
# **Your response here:**
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# ---
#
# # 10. Create Your Own Class
#
# Create a class called `CustomerPlan`.
#
# When an object is created, provide:
#
# - `plan_name`
# - `monthly_charge`
#
# Add a method called `annual_cost()` that returns:
#
# `monthly_charge * 12`

# %%
# TODO

class CustomerPlan:

    def __init__(self, plan_name, monthly_charge):
        pass

    def annual_cost(self):
        pass

# %% [markdown]
# Instantiate a plan with:
#
# - plan name = `"Premium"`
# - monthly charge = `95`
#
# Calculate the annual cost.

# %%
# TODO
premium_plan = None
annual_plan_cost = None

print("Annual plan cost:", annual_plan_cost)

# %% [markdown]
# ---
#
# # 11. Why OOP Matters for Machine Learning
#
# Machine-learning libraries use the same object-oriented pattern.
#
# A typical workflow is:
#
# 1. **Instantiate** a model object.
# 2. Call `.fit()` to train it.
# 3. Call `.predict()` to generate predictions.
#
# Example:
#
# ```python
# model = LogisticRegression()
# model.fit(X, y)
# predictions = model.predict(X_test)
# ```
#
# `LogisticRegression` is a class.
# `model` is an instance of that class.
# `.fit()` and `.predict()` are methods.

# %% [markdown]
# ## Practice 11A: Identify the OOP pieces
#
# Given:
#
# ```python
# model = LogisticRegression()
# model.fit(X, y)
# predictions = model.predict(X_test)
# ```
#
# Identify:
#
# 1. Class:
# 2. Object/instance:
# 3. Training method:
# 4. Prediction method:

# %% [markdown]
# **Your response here:**
# 1.
# 2.
# 3.
# 4.
